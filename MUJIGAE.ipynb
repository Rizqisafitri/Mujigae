# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# for vizualization
import matplotlib
import plotly.express as px
print("Setup Complete")

# %%
# Import dataset
File = 'C:/Users/Q_Q/Documents/LAMARAN/Distribution of Transaction.xlsx'
Data = pd.read_excel(File)

# %% [markdown]
# Data

# %%
Data.dtypes
# Out:
# sub_total           int64
# count(sub_total)    int64
# dtype: object

# %%
Data.dropna(how='any', inplace=True)

print(Data.head(5))
Data.info()
Data.describe()
# Out:
#    sub_total  count(sub_total)
# 0          1                 1
# 1       6061                 3
# 2       7400                 1
# 3       9000                 2
# 4       9090                 2
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2348 entries, 0 to 2347
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sub_total         2348 non-null   int64
#  1   count(sub_total)  2348 non-null   int64
# dtypes: int64(2)
# memory usage: 55.0 KB
#           sub_total  count(sub_total)
# count  2.348000e+03       2348.000000
# mean   1.486735e+05         10.175468
# std    8.374978e+04         64.554709
# min    1.000000e+00          1.000000
# 25%    9.268475e+04          1.000000
# 50%    1.349500e+05          1.000000
# 75%    1.878850e+05          4.000000
# max    1.074400e+06       1638.000000

# %%
from statistics import median
from statistics import mode

# %%
print(Data.median())
# Out:
# sub_total           134950.0
# count(sub_total)         1.0
# dtype: float64

# %%
print(Data.mode())
# Out:
#       sub_total  count(sub_total)
# 0             1               1.0
# 1          6061               NaN
# 2          7400               NaN
# 3          9000               NaN
# 4          9090               NaN
# ...         ...               ...
# 2343     640627               NaN
# 2344     680000               NaN
# 2345     760200               NaN
# 2346     869400               NaN
# 2347    1074400               NaN
#
# [2348 rows x 2 columns]

# %%
# Import dataset
file = 'C:/Users/Q_Q/Documents/LAMARAN/Sales.xlsx'
data = pd.read_excel(file)

# %%
data
# Out:
#        ticket_id  outlet_code outlet_alias        closing_date  menu_id  \
# 0        2101888         1056          DBC 2021-10-07 09:03:35      796
# 1        2101889         1056          DBC 2021-10-07 09:03:35      940
# 2        2101890         1075          DJW 2021-10-07 09:05:10      634
# 3        2101891         1075          DJW 2021-10-07 09:05:10      739
# 4        2101892         1075          DJW 2021-10-07 09:05:10       94
# ...          ...          ...          ...                 ...      ...
# 47952    2148818         1035          DHI 2021-10-17 11:59:33      796
# 47953    2148818         1035          DHI 2021-10-17 11:59:33      796
# 47954    2148819         1056          DBC 2021-10-17 11:59:40      161
# 47955    2148820         1054          DKM 2021-10-17 11:59:54      795
# 47956    2148820         1054          DKM 2021-10-17 11:59:54      795
#
#                                        menu_name category_name  \
# ...

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47957 entries, 0 to 47956
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ticket_id      47957 non-null  int64
#  1   outlet_code    47957 non-null  int64
#  2   outlet_alias   47957 non-null  object
#  3   closing_date   47957 non-null  datetime64[ns]
#  4   menu_id        47957 non-null  int64
#  5   menu_name      47957 non-null  object
#  6   category_name  47957 non-null  object
#  7   group_name     47957 non-null  object
#  8   authorised     47957 non-null  int64
#  9   item_price     47957 non-null  int64
#  10  sub_total      47957 non-null  int64
#  11  order_type     47957 non-null  object
#  12  brand_name     47957 non-null  object
#  13  is_we          47957 non-null  object
#  14  day_of_week    47957 non-null  object
#  15  date_filter    47957 non-null  int64
#  16  hour_filter    47957 non-null  int64
# ...

# %%
import datetime

# %%
data['closing_date'] = pd.to_datetime(data['closing_date']).dt.date
print(data)
# Out:
#        ticket_id  outlet_code outlet_alias closing_date  menu_id  \
# 0        2101888         1056          DBC   2021-10-07      796
# 1        2101889         1056          DBC   2021-10-07      940
# 2        2101890         1075          DJW   2021-10-07      634
# 3        2101891         1075          DJW   2021-10-07      739
# 4        2101892         1075          DJW   2021-10-07       94
# ...          ...          ...          ...          ...      ...
# 47952    2148818         1035          DHI   2021-10-17      796
# 47953    2148818         1035          DHI   2021-10-17      796
# 47954    2148819         1056          DBC   2021-10-17      161
# 47955    2148820         1054          DKM   2021-10-17      795
# 47956    2148820         1054          DKM   2021-10-17      795
#
#                                        menu_name category_name  \
# 0         Paket Dosirak 2 - Korean Chicken Spicy   MAIN COURSE
# ...

# %%
results = data.groupby('closing_date').sum()

# %%
#Sales only 
data.groupby('closing_date').sum()['sub_total']
# Out:
# closing_date
# 2021-10-07    346920508
# 2021-10-08    429766502
# 2021-10-09    446671011
# 2021-10-10    657600321
# 2021-10-11    419078703
# 2021-10-12    346212703
# 2021-10-13    350276307
# 2021-10-14    438487408
# 2021-10-15    389080302
# 2021-10-16    390311307
# 2021-10-17    134246600
# Name: sub_total, dtype: int64

# %%
#Sales only 
data.groupby('closing_date').sum()['sub_total']

# %%
grouped_multiple = data.groupby(['closing_date', 'menu_name','outlet_alias','order_type']).agg({'sub_total': ['mean', 'min', 'max']})
grouped_multiple.columns = ['sub_total_mean', 'sub_total_min', 'sub_total_max']
grouped_multiple = grouped_multiple.reset_index()
print(grouped_multiple)
# Out:
#       closing_date           menu_name outlet_alias order_type  \
# 0       2021-10-07         Air Mineral          DAN     shopee
# 1       2021-10-07         Air Mineral          DBC     shopee
# 2       2021-10-07         Air Mineral          DBS   grabfood
# 3       2021-10-07         Air Mineral          DCB     shopee
# 4       2021-10-07         Air Mineral          DCG   grabfood
# ...            ...                 ...          ...        ...
# 26115   2021-10-17  Topokki With Mandu          DPS   grabfood
# 26116   2021-10-17  Topokki With Mandu          DSD     gofood
# 26117   2021-10-17  Topokki With Mandu          DSW     gofood
# 26118   2021-10-17  Topokki With Mandu          DSW     shopee
# 26119   2021-10-17  Topokki With Mandu          DTE   grabfood
#
#        sub_total_mean  sub_total_min  sub_total_max
# 0             31000.0          31000          31000
# 1             41500.0          41500          41500
# ...
